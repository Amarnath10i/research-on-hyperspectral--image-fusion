# %%
# !pip install tensorflow==1.15.* numpy scipy scikit-image opencv-python scikit-image

# %%
# !pip install sewar scikit-image

# %%
cd /kaggle/working
# Out:
# /kaggle/working

# %%
# !rm -rf /kaggle/working/hif-benchmarking

# %%
# !git clone https://github.com/Nikesh0907/hif-benchmarking.git
# Out:
# Cloning into 'hif-benchmarking'...
# remote: Enumerating objects: 3152, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 3152 (delta 3), reused 0 (delta 0), pack-reused 3148 (from 2)
# Receiving objects: 100% (3152/3152), 635.85 MiB | 43.57 MiB/s, done.
# Resolving deltas: 100% (1059/1059), done.
# Updating files: 100% (2470/2470), done.

# %%
cd /kaggle/working/hif-benchmarking
# Out:
# /kaggle/working/hif-benchmarking

# %%
# !python methods/_DBIN/dbintest.py \
    /kaggle/input/cave-dataset-2/Data/Test/HSI \
    --model_dir "/kaggle/input/model-sf16-15k/tensorflow2/default/1" \
    --rgb_dir /kaggle/input/cave-dataset-2/Data/Test/RGB \
    --num_images 12
# Out:
# 2026-04-25 12:32:46.425724: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777120366.446868     156 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777120366.453851     156 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777120366.472037     156 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
